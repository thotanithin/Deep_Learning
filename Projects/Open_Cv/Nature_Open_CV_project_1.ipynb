# %%
import cv2
import numpy as np

# %% [markdown]
# # DEFORESTATION

# %%
# Day
black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
black=cv2.circle(black,(870,250),70,(51,110,0),-2)
black=cv2.circle(black,(830,280),70,(51,110,0),-2)
black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

#cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\subject.jpg",black)

# %%
# night
black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
black=cv2.circle(black,(870,250),70,(51,110,0),-2)
black=cv2.circle(black,(830,280),70,(51,110,0),-2)
black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Sun

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
black=cv2.circle(black,(250,120),40,(43,172,250),-2) -2

black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.circle(black,(750,120),40,(43,172,250),-2) -2
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Moon

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground

black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

black=cv2.circle(black,(500,50),30,(201,201,201),-2)

black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Day
black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(161,135,83),200) #day

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
black=cv2.circle(black,(870,250),70,(51,110,0),-2)
black=cv2.circle(black,(830,280),70,(51,110,0),-2)
black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

black=cv2.circle(black,(900,230),7,(51,87,255),-1)#Oranges2
black=cv2.circle(black,(800,300),7,(51,87,255),-1)#Oranges2
black=cv2.circle(black,(946,310),7,(51,87,255),-1)#Oranges2
black=cv2.circle(black,(816,227),7,(51,87,255),-1)#Oranges2
black=cv2.circle(black,(871,276),7,(51,87,255),-1)#Oranges2

black=cv2.circle(black,(502,295),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(382,292),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(400,200),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(601,266),7,(51,87,255),-1)#Oranges3


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img0.jpg",black)
# Out:
# True

# %%
# Road img1
# Day
img1=np.zeros((500,1000,3),np.uint8)

img1=cv2.rectangle(img1,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img1=cv2.rectangle(img1,(0,0),(1000,200),(244,191,155),200) #day
img1=cv2.circle(img1,(50,250),40,(43,172,250),-2) # sun 1

img1=cv2.line(img1,(145,300),(145,450),(11,71,110),30) # Trees 01
img1=cv2.line(img1,(145,300),(125,450),(11,71,110),30)
img1=cv2.line(img1,(145,300),(165,450),(11,71,110),30)
img1=cv2.circle(img1,(145,250),70,(51,110,0),-2)
img1=cv2.circle(img1,(90,280),50,(51,110,0),-2)
img1=cv2.circle(img1,(190,280),70,(51,110,0),-2)

img1=cv2.line(img1,(870,300),(870,450),(11,71,110),30) # Trees 02
img1=cv2.line(img1,(870,300),(850,450),(11,71,110),30)
img1=cv2.line(img1,(870,300),(890,450),(11,71,110),30)
img1=cv2.circle(img1,(870,250),70,(51,110,0),-2)
img1=cv2.circle(img1,(830,280),70,(51,110,0),-2)
img1=cv2.circle(img1,(900,280),70,(51,110,0),-2)

img1=cv2.line(img1,(500,210),(500,500),(11,71,110),50) # Trees 03
img1=cv2.line(img1,(500,210),(480,500),(11,71,110),50)
img1=cv2.line(img1,(500,210),(520,500),(11,71,110),50)
img1=cv2.circle(img1,(500,200),100,(51,110,0),-2)
img1=cv2.circle(img1,(450,230),90,(51,110,0),-2)
img1=cv2.circle(img1,(550,230),90,(51,110,0),-2)
img1=cv2.circle(img1,(435,282),90,(51,110,0),-2)
img1=cv2.circle(img1,(575,282),70,(51,110,0),-2)

img1=cv2.line(img1,(720,290),(720,350),(11,71,110),15) # Trees 04
img1=cv2.line(img1,(720,290),(710,350),(11,71,110),15)
img1=cv2.line(img1,(720,290),(730,350),(11,71,110),15)
img1=cv2.circle(img1,(720,280),30,(51,110,0),-2)
img1=cv2.circle(img1,(700,285),30,(51,110,0),-2)
img1=cv2.circle(img1,(740,285),30,(51,110,0),-2)

img1=cv2.circle(img1,(190,461),20,(0,90,45),-2) # Grass 1
img1=cv2.circle(img1,(170,480),20,(0,90,45),-2)
img1=cv2.circle(img1,(210,480),20,(0,90,45),-2)
img1=cv2.circle(img1,(170,490),30,(0,90,45),-2)
img1=cv2.line(img1,(200,461),(220,420),(0,200,150),2)# flower
img1=cv2.circle(img1,(220,420),10,(0,0,200),-2)
img1=cv2.circle(img1,(230,410),10,(0,0,200),-2)
img1=cv2.circle(img1,(210,410),10,(0,0,200),-2)
img1=cv2.circle(img1,(230,430),10,(0,0,200),-2)
img1=cv2.circle(img1,(210,430),10,(0,0,200),-2)
img1=cv2.circle(img1,(220,420),5,(0,191,255),-2)
img1=cv2.circle(img1,(220,420),2,(0,0,0),-2)

img1=cv2.circle(img1,(697,421),30,(0,90,45),-2) # Grass 2
img1=cv2.circle(img1,(687,440),25,(0,90,45),-2)
img1=cv2.circle(img1,(720,435),30,(0,90,45),-2)
img1=cv2.circle(img1,(750,440),20,(0,90,45),-2)

img1=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
img1=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
img1=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
img1=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
img1=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

img1=cv2.circle(black,(900,230),7,(51,87,255),-1)#Oranges2
img1=cv2.circle(black,(800,300),7,(51,87,255),-1)#Oranges2
img1=cv2.circle(black,(946,310),7,(51,87,255),-1)#Oranges2
img1=cv2.circle(black,(816,227),7,(51,87,255),-1)#Oranges2
img1=cv2.circle(black,(871,276),7,(51,87,255),-1)#Oranges2

img1=cv2.circle(black,(502,295),7,(51,87,255),-1)#Oranges3
img1=cv2.circle(black,(382,292),7,(51,87,255),-1)#Oranges3
img1=cv2.circle(black,(400,200),7,(51,87,255),-1)#Oranges3
img1=cv2.circle(black,(601,266),7,(51,87,255),-1)#Oranges3

# off-road
img1=cv2.rectangle(img1,(1050,360),(900,500),(0,63,123),-50)



cv2.imshow("circle",img1)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img1.jpg",img1)
# Out:
# True

# %%
# Day img2

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(250,120),40,(43,172,250),-2) # -2

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(800,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

# black=cv2.circle(black,(900,230),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(800,300),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(946,310),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(816,227),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(871,276),7,(51,87,255),-1)#Oranges2

black=cv2.circle(black,(502,295),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(382,292),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(400,200),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(601,266),7,(51,87,255),-1)#Oranges3


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img2.jpg",black)
# Out:
# True

# %%
# Day img3

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(500,50),40,(43,172,250),-2) #sun

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(600,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

# black=cv2.circle(black,(900,230),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(800,300),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(946,310),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(816,227),7,(51,87,255),-1)#Oranges2
# black=cv2.circle(black,(871,276),7,(51,87,255),-1)#Oranges2

black=cv2.circle(black,(502,295),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(382,292),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(400,200),7,(51,87,255),-1)#Oranges3
black=cv2.circle(black,(601,266),7,(51,87,255),-1)#Oranges3


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img3.jpg",black)
# Out:
# True

# %%
# Day img4

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2)  #sun

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(400,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img4.jpg",black)
# Out:
# True

# %%
# Day img5

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img5.jpg",black)
# Out:
# True

# %%
# Day img6

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img6.jpg",black)
# Out:
# True

# %%
# Day img7

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1
cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img7.jpg",black)
# Out:
# True

# %%
# night img8

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(50,250),40,(201,201,201),-2) # moon 1

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img8.jpg",black)
# Out:
# True

# %%
# night img9

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(50,250),40,(201,201,201),-2) # moon 1


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

# black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img9.jpg",black)
# Out:
# True

# %%
# night img10

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(250,120),40,(201,201,201),-2) #moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img10.jpg",black)
# Out:
# True

# %%
# night img11

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(250,120),40,(201,201,201),-2) #moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img11.jpg",black)
# Out:
# True

# %%
# night img12

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(250,120),40,(201,201,201),-2) #moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img12.jpg",black)
# Out:
# True

# %%
# night img13

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(500,50),40,(201,201,201),-2) # moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img13.jpg",black)
# Out:
# True

# %%
# night img14

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(500,50),40,(201,201,201),-2) # moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img14.jpg",black)
# Out:
# True

# %%
# night img15

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(750,120),40,(201,201,201),-2) # moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

# black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img15.jpg",black)
# Out:
# True

# %%
# night img16

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(950,250),40,(201,201,201),-2) # moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

# black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img16.jpg",black)
# Out:
# True

# %%
# night img17

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
# black=cv2.circle(black,(950,250),40,(201,201,201),-2) # moon


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

# black=cv2.circle(black,(350,190),5,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),5,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),5,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),5,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),5,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),5,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),5,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),5,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),5,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),5,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),5,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),5,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),5,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),5,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),5,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img17.jpg",black)
# Out:
# True

# %%
# day img18

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(161,135,83),200) #day


black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),50,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(200,500),(0,63,123),-50)

black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img18.jpg",black)
# Out:
# True

# %%
# day img19

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1

# black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
# black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
# black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
# black=cv2.circle(black,(145,250),70,(51,110,0),-2)
# black=cv2.circle(black,(90,280),50,(51,110,0),-2)
# black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(100,500),(0,63,123),-50)

# black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
# black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img19.jpg",black)
# Out:
# True

# %%
# day img20

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(250,120),40,(43,172,250),-2) # sun 

# black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
# black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
# black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
# black=cv2.circle(black,(145,250),70,(51,110,0),-2)
# black=cv2.circle(black,(90,280),50,(51,110,0),-2)
# black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
# black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50)

# black=cv2.circle(black,(145,250),7,(51,87,255),-2) #Oranges1
# black=cv2.circle(black,(120,280),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(50,280),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(180,220),7,(51,87,255),-2)#Oranges1
# black=cv2.circle(black,(190,280),7,(51,87,255),-2)#Oranges1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img20.jpg",black)
# Out:
# True

# %%
# day img21

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(500,50),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
# black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(575,320),(32,164,217),3)


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)



# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)


# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img21.jpg",black)
# Out:
# True

# %%
# day img22

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(500,50),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
# black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(575,320),(32,164,217),3)


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)



# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)


# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img22.jpg",black)
# Out:
# True

# %%
# day img23

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
# black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img23.jpg",black)
# Out:
# True

# %%
# day img24

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img24.jpg",black)
# Out:
# True

# %%
# day img24

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
# black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img24.jpg",black)
# Out:
# True

# %%
# day img25

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun 


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img25.jpg",black)
# Out:
# True

# %%
# night img26

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img26.jpg",black)
# Out:
# True

# %%
# night img27

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(50,250),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img27.jpg",black)
# Out:
# True

# %%
# night img28

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(250,120),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img28.jpg",black)
# Out:
# True

# %%
# night img29

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(500,50),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img29.jpg",black)
# Out:
# True

# %%
# night img30

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(750,120),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img30.jpg",black)
# Out:
# True

# %%
# night img31

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
black=cv2.circle(black,(950,250),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img31.jpg",black)
# Out:
# True

# %%
# night img32

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) #moon


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img32.jpg",black)
# Out:
# True

# %%
# day img33

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(161,135,83),200) #day


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img33.jpg",black)
# Out:
# True

# %%
# day img34

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(50,250),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
# black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img34.jpg",black)
# Out:
# True

# %%
# day img34

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(50,250),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img34.jpg",black)
# Out:
# True

# %%
# day img35

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(250,120),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img35.jpg",black)
# Out:
# True

# %%
# day img36

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(250,120),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
# black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img36.jpg",black)
# Out:
# True

# %%
# day img37

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img37.jpg",black)
# Out:
# True

# %%
# day img38

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
# black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img38.jpg",black)
# Out:
# True

# %%
# day img39

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day
black=cv2.circle(black,(750,120),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img39.jpg",black)
# Out:
# True

# %%
# day img40

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day
black=cv2.circle(black,(950,250),40,(43,172,250),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img40.jpg",black)
# Out:
# True

# %%
# day img41

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day


black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img41.jpg",black)
# Out:
# True

# %%
# night img42

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img42.jpg",black)
# Out:
# True

# %%
# night img43

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img43.jpg",black)
# Out:
# True

# %%
# night img44

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
black=cv2.circle(black,(50,250),30,(201,201,201),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img44.jpg",black)
# Out:
# True

# %%
# night img45

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
black=cv2.circle(black,(250,120),30,(201,201,201),-2) #moon

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img45.jpg",black)
# Out:
# True

# %%
# night img46

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
black=cv2.circle(black,(500,50),30,(201,201,201),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img46.jpg",black)
# Out:
# True

# %%
# night img47

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
black=cv2.circle(black,(500,50),30,(201,201,201),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img47.jpg",black)
# Out:
# True

# %%
# night img48

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img48.jpg",black)
# Out:
# True

# %%
# night img49

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img49.jpg",black)
# Out:
# True

# %%
# night img50

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img50.jpg",black)
# Out:
# True

# %%
# day img51

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(161,135,83),200) #day

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img51.jpg",black)
# Out:
# True

# %%
# day img52

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


# black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
# black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img52.jpg",black)
# Out:
# True

# %%
# day img53

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
# black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img53.jpg",black)
# Out:
# True

# %%
# day img54

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
# black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
# black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img54.jpg",black)
# Out:
# True

# %%
# day img55

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
# black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img55.jpg",black)
# Out:
# True

# %%
# day img56

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
# black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img56.jpg",black)
# Out:
# True

# %%
# day img56

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
# black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img57.jpg",black)
# Out:
# True

# %%
# day img58

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
# black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img58.jpg",black)
# Out:
# True

# %%
# day img59

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img59.jpg",black)
# Out:
# True

# %%
# day img60

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(129,109,86),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)



cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img60.jpg",black)
# Out:
# True

# %%
# night img61

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img61.jpg",black)
# Out:
# True

# %%
# night img62

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img62.jpg",black)
# Out:
# True

# %%
# night img63

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img63.jpg",black)
# Out:
# True

# %%
# night img64

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img64.jpg",black)
# Out:
# True

# %%
# night img65

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img65.jpg",black)
# Out:
# True

# %%
# night img66

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img66.jpg",black)
# Out:
# True

# %%
# night img66

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img66.jpg",black)
# Out:
# True

# %%
# night img67

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img67.jpg",black)
# Out:
# True

# %%
# night img68

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
# black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img68.jpg",black)
# Out:
# True

# %%
# night img69

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

# black=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1
# black=cv2.circle(black,(250,120),30,(201,201,201),-2) #-2

# black=cv2.circle(black,(500,50),30,(201,201,201),-2)

# black=cv2.circle(black,(750,120),30,(201,201,201),-2) #-2
# black=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

# black=cv2.circle(black,(350,190),2,(0, 234, 255),-2) # insects 1
# black=cv2.circle(black,(250,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(10,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(30,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(450,190),2,(0, 234, 255),-2) # insects 2
# black=cv2.circle(black,(450,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(590,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(620,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(810,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(930,210),2,(0, 234, 255),-2)


# black=cv2.circle(black,(950,190),2,(0, 234, 255),-2) # insects 3
# black=cv2.circle(black,(950,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(890,300),2,(0, 234, 255),-2)
# black=cv2.circle(black,(820,200),2,(0, 234, 255),-2)
# black=cv2.circle(black,(910,350),2,(0, 234, 255),-2)
# black=cv2.circle(black,(830,210),2,(0, 234, 255),-2)

# black=cv2.circle(black,(550,490),2,(0, 234, 255),-2) # insects 4
# black=cv2.circle(black,(550,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(8590,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(520,400),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(910,450),2,(0, 234, 255),-2)
# # black=cv2.circle(black,(530,410),2,(0, 234, 255),-2)
# black=cv2.circle(black,(110,450),2,(0, 234, 255),-2)
# black=cv2.circle(black,(130,410),2,(0, 234, 255),-2)

# black=cv2.circle(black,(350,470),2,(0, 234, 255),-2) # insects 5
# black=cv2.circle(black,(250,474),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,480),2,(0, 234, 255),-2)
# black=cv2.circle(black,(50,430),2,(0, 234, 255),-2)

#Stars
black=cv2.circle(black,(950,120),3,(255, 255, 255),-1) # stars
# black=cv2.circle(black,(950,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,200),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,120),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,250),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,210),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,150),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,240),3,(255, 255, 255),-1)
# black=cv2.circle(black,(50,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(10,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(30,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(450,100),3,(255, 255, 255),-2)
# black=cv2.circle(black,(450,200),3,(255, 255, 255),-2)
# black=cv2.circle(black,(590,120),3,(255, 255, 255),-2)
# black=cv2.circle(black,(620,50),3,(255, 255, 255),-2)
# black=cv2.circle(black,(810,70),3,(255, 255, 255),-2)
# black=cv2.circle(black,(930,80),3,(255, 255, 255),-2)
# black=cv2.circle(black,(950,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(950,50),3,(255, 255, 255),-1)
# black=cv2.circle(black,(890,55),3,(255, 255, 255),-1)
# black=cv2.circle(black,(820,65),3,(255, 255, 255),-1)
# black=cv2.circle(black,(910,20),3,(255, 255, 255),-1)
# black=cv2.circle(black,(730,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(250,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(550,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(510,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(430,75),3,(255, 255, 255),-1)
# black=cv2.circle(black,(330,25),3,(255, 255, 255),-1)
# black=cv2.circle(black,(350,90),3,(255, 255, 255),-1) 
# black=cv2.circle(black,(350,10),3,(255, 255, 255),-1)
# black=cv2.circle(black,(250,80),3,(255, 255, 255),-1)
# black=cv2.circle(black,(380,68),3,(255, 255, 255),-1)
# black=cv2.circle(black,(280,45),3,(255, 255, 255),-1)
# black=cv2.circle(black,(320,75),3,(255, 255, 255),-1)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img69.jpg",black)
# Out:
# True

# %%
# day img70

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(161,135,83),200) #day

# black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img70.jpg",black)
# Out:
# True

# %%
# day img70

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
# black=cv2.circle(black,(250,120),40,(43,172,250),-2) #-2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2)

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) #-2
# black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

# off-road
black=cv2.rectangle(black,(1050,360),(0,500),(0,63,123),-50) 


# # Huts
black=cv2.rectangle(black,(550,360),(600,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(550,360),(600,310),(25, 54, 90),-10) # hut 1
black=cv2.line(black,(570,290),(520,320),(32,164,217),3)
black=cv2.line(black,(570,290),(630,320),(32,164,217),3)
black=cv2.line(black,(570,290),(540,320),(32,164,217),3)
black=cv2.line(black,(570,290),(610,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(600,320),(32,164,217),3)
black=cv2.line(black,(570,290),(550,320),(32,164,217),3)
black=cv2.line(black,(570,290),(590,320),(32,164,217),3)
black=cv2.line(black,(570,290),(560,320),(32,164,217),3)
black=cv2.line(black,(570,290),(580,320),(32,164,217),3)
black=cv2.line(black,(570,290),(570,320),(32,164,217),3)
black=cv2.line(black,(570,290),(575,320),(32,164,217),3)
black=cv2.rectangle(black,(570,360),(580,340),(32,164,217),2) # door


black=cv2.rectangle(black,(350,360),(400,340),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(350,360),(400,310),(25, 54, 90),-10) # hut 2
black=cv2.line(black,(370,290),(320,320),(32,164,217),3)
black=cv2.line(black,(370,290),(430,320),(32,164,217),3)
black=cv2.line(black,(370,290),(340,320),(32,164,217),3)
black=cv2.line(black,(370,290),(420,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(410,320),(32,164,217),3)
black=cv2.line(black,(370,290),(350,320),(32,164,217),3)
black=cv2.line(black,(370,290),(400,320),(32,164,217),3)
black=cv2.line(black,(370,290),(360,320),(32,164,217),3)
black=cv2.line(black,(370,290),(380,320),(32,164,217),3)
black=cv2.line(black,(370,290),(370,320),(32,164,217),3)
black=cv2.line(black,(370,290),(390,320),(32,164,217),3)
black=cv2.rectangle(black,(370,360),(380,340),(32,164,217),2) # door


black=cv2.rectangle(black,(150,360),(200,325),(25, 54, 90),-10) # half hut
black=cv2.rectangle(black,(150,360),(200,310),(25, 54, 90),-10) # hut 3
black=cv2.line(black,(170,290),(130,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(230,320),(32,164,217),3)
black=cv2.line(black,(170,290),(140,320),(32,164,217),3)
black=cv2.line(black,(170,290),(220,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(210,320),(32,164,217),3)
black=cv2.line(black,(170,290),(150,320),(32,164,217),3)
black=cv2.line(black,(170,290),(200,320),(32,164,217),3)
black=cv2.line(black,(170,290),(160,320),(32,164,217),3)
black=cv2.line(black,(170,290),(180,320),(32,164,217),3)
black=cv2.line(black,(170,290),(170,320),(32,164,217),3)
black=cv2.line(black,(170,290),(190,320),(32,164,217),3)
black=cv2.rectangle(black,(170,360),(180,340),(32,164,217),2) # door

# # Farm land
black=cv2.line(black,(0,380),(1000,380),(0,100,0),20)
black=cv2.line(black,(170,380),(300,500),(0,100,0),20)
black=cv2.line(black,(380,380),(550,500),(0,100,0),20)
black=cv2.line(black,(600,380),(850,500),(0,100,0),20)

cv2.destroyAllWindows()
cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img71.jpg",black)
# Out:
# True

# %%
# img3=cv2.imread(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img71.jpg")
# values = [] 
# def draw(event,x,y,flag,par):
#     if event == cv2.EVENT_FLAG_LBUTTON: 
#         cv2.circle(img3,(x,y),1,(128,128,128),-1)
#         values.append((x,y))
#         if len(values)>=2:
#             cv2.line(img3,values[-2],values[-1],(10,152,65),2)
#             values.clear()
#     if event == cv2.EVENT_FLAG_RBUTTON:
#         cv2.circle(img3,(x,y),20,(128,128,128),-1) 
# cv2.namedWindow('window',cv2.WINDOW_NORMAL) 
# cv2.setMouseCallback('window',draw)
# count=1
# while True:
#     cv2.imshow('window', img3)
#     key = cv2.waitKey(1) & 0xFF

#     if key == ord('s'):
#         filename = r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img71.jpg"
#         cv2.imwrite(filename, img3)
#         count += 1 
#     if key == ord('q'):
#         break
# cv2.destroyAllWindows()

# %% [markdown]
# # URBANIZATION

# %%
# Sun

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

# black=cv2.circle(black,(50,200),40,(43,172,250),-2) # sun 1

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
black=cv2.circle(black,(870,250),70,(51,110,0),-2)
black=cv2.circle(black,(830,280),70,(51,110,0),-2)
black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)


# black=cv2.circle(black,(250,120),40,(43,172,250),-2)# sun_2

# black=cv2.circle(black,(500,50),40,(43,172,250),-2) # sun_3

# black=cv2.circle(black,(750,120),40,(43,172,250),-2) # sun_4
black=cv2.circle(black,(950,150),40,(43,172,250),-2) # sun_5

cv2.imshow("Project",black)
cv2.waitKey()
cv2.destroyAllWindows()
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image5.jpg",black)

# %%
# buliding_1
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) # morning sky

black=cv2.circle(black,(50,200),30,(43,172,250),-2) # sun_1

# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(50,200),30,(43,172,250),-2)

#  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# road_rectangle
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# # building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


# #footh_path_line
balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image6.jpg",black)

# %%
# buliding_2
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) # morning sky

# black=cv2.circle(black,(50,200),30,(43,172,250),-2)#sun_1
black=cv2.circle(black,(250,120),30,(43,172,250),-2)#sun_2
# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)


# road_rectangle
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


# #footh_path_line
balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# # footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

# #middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
# balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image7.jpg",black)

# %%
# buliding_3
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) # morning sky



# black=cv2.circle(black,(50,200),30,(43,172,250),-2)#sun_1
# black=cv2.circle(black,(250,120),30,(43,172,250),-2)#sun_2
black=cv2.circle(black,(500,50),30,(43,172,250),-2)#sun_3

# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)


# road_rectangle
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(395,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image8.jpg",black)

# %%
# buliding_4
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) # morning sky



# Trees 01
# black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
# black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
# black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
# black=cv2.circle(black,(145,250),70,(51,110,0),-2)
# black=cv2.circle(black,(90,280),70,(51,110,0),-2)
# black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# # Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# # Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
#     # Grass 1
# # black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# # black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# # black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# # black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# # black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
# # black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# # black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# # black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# # black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# # black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# # black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# # black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# #  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# black=cv2.circle(black,(50,200),30,(43,172,250),-2)#sun_1
# black=cv2.circle(black,(250,120),30,(43,172,250),-2)#sun_2
# black=cv2.circle(black,(500,50),30,(43,172,250),-2)#sun_3
black=cv2.circle(black,(750,120),30,(43,172,250),-2) # sun_4
# black=cv2.circle(black,(950,150),40,(43,172,250),-2) # sun_5


# road_rectangle_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle_2
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle_3
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(400,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line


# road_rectangle_4
black =cv2.rectangle(black,(0,400),(314,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(0,350),(314,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(0,450),(70,450),(255,255,255),1)#middle_line
black= cv2.line(black,(90,450),(160,450),(255,255,255),1)#middle_line
black= cv2.line(black,(190,450),(250,450),(255,255,255),1)#middle_line
black= cv2.line(black,(260,450),(314,450),(255,255,255),1)#middle_line

# building  RGB _3
black = cv2.rectangle(black,(90,180),(220,310),(14,65,183),-1)#building RGB 183, 65, 14
black = cv2.rectangle(black,(140,309),(170,266),(86,210,93),2)#door 
black = cv2.rectangle(black,(105,248),(120,238),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(185,248),(200,238),(0,133,242),2)# windows


#footh_path_line
balck = cv2.line(black,(110,350),(110,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(312,350),(312,400),((0,0,0)),5)#footh_path_line

# black=cv2.line(black,(280,270),(280,330),(11,71,110),10) # Trees 
# black=cv2.line(black,(250,290),(240,350),(11,71,110),10)
# black=cv2.line(black,(250,290),(2600,350),(11,71,110),10)
# black=cv2.circle(black,(250,280),20,(51,110,0),-2)
# black=cv2.circle(black,(260,285),20,(51,110,0),-2)
# black=cv2.circle(black,(290,285),20,(51,110,0),-2)

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image9.jpg",black)

# %%
# buliding_5
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) # morning sky



# Trees 01
# black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
# black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
# black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
# black=cv2.circle(black,(145,250),70,(51,110,0),-2)
# black=cv2.circle(black,(90,280),70,(51,110,0),-2)
# black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# # Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# # Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
#     # Grass 1
# # black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
# # black=cv2.circle(black,(170,480),20,(0,90,45),-2)
# # black=cv2.circle(black,(210,480),20,(0,90,45),-2)
# # black=cv2.circle(black,(170,490),30,(0,90,45),-2)
# # black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
# # black=cv2.circle(black,(220,420),10,(0,0,200),-2)
# # black=cv2.circle(black,(230,410),10,(0,0,200),-2)
# # black=cv2.circle(black,(210,410),10,(0,0,200),-2)
# # black=cv2.circle(black,(230,430),10,(0,0,200),-2)
# # black=cv2.circle(black,(210,430),10,(0,0,200),-2)
# # black=cv2.circle(black,(220,420),5,(0,191,255),-2)
# # black=cv2.circle(black,(220,420),2,(0,0,0),-2)

# #  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# black=cv2.circle(black,(50,200),30,(43,172,250),-2)#sun_1
# black=cv2.circle(black,(250,120),30,(43,172,250),-2)#sun_2
# black=cv2.circle(black,(500,50),30,(43,172,250),-2)#sun_3
# black=cv2.circle(black,(750,120),30,(43,172,250),-2) # sun_4
black=cv2.circle(black,(950,190),30,(43,172,250),-2) # sun_5


# road_rectangle_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle_2
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle_3
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(400,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line


# road_rectangle_4
black =cv2.rectangle(black,(0,400),(314,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(0,350),(314,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(0,450),(70,450),(255,255,255),1)#middle_line
black= cv2.line(black,(90,450),(160,450),(255,255,255),1)#middle_line
black= cv2.line(black,(190,450),(250,450),(255,255,255),1)#middle_line
black= cv2.line(black,(260,450),(314,450),(255,255,255),1)#middle_line

# building  RGB _3
black = cv2.rectangle(black,(90,180),(220,310),(14,65,183),-1)#building RGB 183, 65, 14
black = cv2.rectangle(black,(140,309),(170,266),(86,210,93),2)#door 
black = cv2.rectangle(black,(105,248),(120,238),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(185,248),(200,238),(0,133,242),2)# windows


#footh_path_line
balck = cv2.line(black,(110,350),(110,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(312,350),(312,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
# cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image10.jpg",black)

# %%
# night_1

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground  


black=cv2.circle(black,(50,120),30,(201,201,201),-2) #moon_1

# stars
black=cv2.circle(black,(900,150),2,(255,255,255),1)
black=cv2.circle(black,(700,20),2,(255,255,255),1)
black=cv2.circle(black,(600,70),2,(255,255,255),1)
black=cv2.circle(black,(550,50),2,(255,255,255),1)
balck=cv2.circle(black,(350,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)
black=cv2.circle(black,(900,100),2,(255,255,255),1)
black=cv2.circle(black,(800,120),2,(255,255,255),1)
black=cv2.circle(black,(500,100),2,(255,255,255),1)
black=cv2.circle(black,(450,50),2,(255,255,255),1)
balck=cv2.circle(black,(250,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# road_rectangle_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line






cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image11.jpg",black)

# %%
# night_2

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground  

black=cv2.circle(black,(250,120),30,(201,201,201),-2) # moon_2

# stars
black=cv2.circle(black,(900,150),2,(255,255,255),1)
black=cv2.circle(black,(700,20),2,(255,255,255),1)
black=cv2.circle(black,(600,70),2,(255,255,255),1)
black=cv2.circle(black,(550,50),2,(255,255,255),1)
balck=cv2.circle(black,(350,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)
black=cv2.circle(black,(900,100),2,(255,255,255),1)
black=cv2.circle(black,(800,120),2,(255,255,255),1)
black=cv2.circle(black,(500,100),2,(255,255,255),1)
black=cv2.circle(black,(450,50),2,(255,255,255),1)
balck=cv2.circle(black,(250,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
# black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
# black=cv2.circle(black,(687,440),25,(0,90,45),-2)
# black=cv2.circle(black,(720,435),30,(0,90,45),-2)
# black=cv2.circle(black,(750,440),20,(0,90,45),-2)

# road_rectangle_2
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line

# road_rectangele_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image12.jpg",black)

# %%
black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground 
black=cv2.circle(black,(500,50),30,(201,201,201),-2) #moon_3

# stars
black=cv2.circle(black,(900,150),2,(255,255,255),1)
black=cv2.circle(black,(700,20),2,(255,255,255),1)
black=cv2.circle(black,(600,70),2,(255,255,255),1)
black=cv2.circle(black,(550,50),2,(255,255,255),1)
balck=cv2.circle(black,(350,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)
black=cv2.circle(black,(900,100),2,(255,255,255),1)
black=cv2.circle(black,(800,120),2,(255,255,255),1)
black=cv2.circle(black,(500,100),2,(255,255,255),1)
black=cv2.circle(black,(450,50),2,(255,255,255),1)
balck=cv2.circle(black,(250,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

# Trees 01
black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

# Trees 04
# black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 04
# black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
# black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
# black=cv2.circle(black,(870,250),70,(51,110,0),-2)
# black=cv2.circle(black,(830,280),70,(51,110,0),-2)
# black=cv2.circle(black,(900,280),70,(51,110,0),-2)

# Trees 02
# black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 02
# black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
# black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
# black=cv2.circle(black,(500,200),100,(51,110,0),-2)
# black=cv2.circle(black,(450,230),90,(51,110,0),-2)
# black=cv2.circle(black,(550,230),90,(51,110,0),-2)
# black=cv2.circle(black,(435,282),90,(51,110,0),-2)
# black=cv2.circle(black,(575,282),70,(51,110,0),-2)

# Trees 03
# black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 03
# black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
# black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
# black=cv2.circle(black,(720,280),30,(51,110,0),-2)
# black=cv2.circle(black,(700,285),30,(51,110,0),-2)
# black=cv2.circle(black,(740,285),30,(51,110,0),-2)
 
    # Grass 1
black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower_1
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

#  Grass 2
black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)


# road_rectangle
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(395,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line

cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image13.jpg",black)

# %%
# night_4

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground 
black=cv2.circle(black,(750,120),30,(201,201,201),-2)  #moon_4

# stars
black=cv2.circle(black,(900,150),2,(255,255,255),1)
black=cv2.circle(black,(700,20),2,(255,255,255),1)
black=cv2.circle(black,(600,70),2,(255,255,255),1)
black=cv2.circle(black,(550,50),2,(255,255,255),1)
balck=cv2.circle(black,(350,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)
black=cv2.circle(black,(900,100),2,(255,255,255),1)
black=cv2.circle(black,(800,120),2,(255,255,255),1)
black=cv2.circle(black,(500,100),2,(255,255,255),1)
black=cv2.circle(black,(450,50),2,(255,255,255),1)
balck=cv2.circle(black,(250,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

black=cv2.circle(black,(80,100),2,(255,255,255),1)
black=cv2.circle(black,(150,50),2,(255,255,255),1)
balck=cv2.circle(black,(200,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

# road_rectangle_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle_2
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle_3
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(400,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line


# road_rectangle_4
black =cv2.rectangle(black,(0,400),(314,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(0,350),(314,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(0,450),(70,450),(255,255,255),1)#middle_line
black= cv2.line(black,(90,450),(160,450),(255,255,255),1)#middle_line
black= cv2.line(black,(190,450),(250,450),(255,255,255),1)#middle_line
black= cv2.line(black,(260,450),(314,450),(255,255,255),1)#middle_line

# building  RGB _3
black = cv2.rectangle(black,(90,180),(220,310),(14,65,183),-1)#building RGB 183, 65, 14
black = cv2.rectangle(black,(140,309),(170,266),(86,210,93),2)#door 
black = cv2.rectangle(black,(105,248),(120,238),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(185,248),(200,238),(0,133,242),2)# windows


#footh_path_line
balck = cv2.line(black,(110,350),(110,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(312,350),(312,400),((0,0,0)),5)#footh_path_line


cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image14.jpg",black)

# %%
# night_5

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground 

# black=cv2.circle(black,(50,120),40,(201,201,201),-2) #moon_1

black=cv2.circle(black,(950,150),30,(201,201,201),-2) # moon_4
# stars
black=cv2.circle(black,(900,150),2,(255,255,255),1)
black=cv2.circle(black,(700,20),2,(255,255,255),1)
black=cv2.circle(black,(600,70),2,(255,255,255),1)
black=cv2.circle(black,(550,50),2,(255,255,255),1)
# balck=cv2.circle(black,(350,75),3,(255,255,255),1)
# black = cv2.circle(black,(50,100),4,(255,255,255),1)
black=cv2.circle(black,(900,100),2,(255,255,255),1)
black=cv2.circle(black,(800,120),2,(255,255,255),1)
black=cv2.circle(black,(500,100),2,(255,255,255),1)
black=cv2.circle(black,(450,50),2,(255,255,255),1)
# balck=cv2.circle(black,(250,75),3,(255,255,255),1)
# black = cv2.circle(black,(50,100),4,(255,255,255),1)

black=cv2.circle(black,(80,100),2,(255,255,255),1)
black=cv2.circle(black,(150,50),2,(255,255,255),1)
balck=cv2.circle(black,(200,75),3,(255,255,255),1)
black = cv2.circle(black,(50,100),4,(255,255,255),1)

# road_rectangle_1
black =cv2.rectangle(black,(750,400),(1000,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(750,350),(1000,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(750,450),(810,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(830,450),(890,450),(255,255,255),1)#middle_line
black= cv2.line(black,(920,450),(1000,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(797,200),(917,327),(255,206,85),-1)#building
black = cv2.rectangle(black,(845,326),(865,296),(255,255,255),2)#door 
black = cv2.rectangle(black,(814,258),(824,248),(0,234,255),2)# leftwindows_1
black = cv2.rectangle(black,(877,258),(887,248),(0,234,255),2)# windows


#footh_path_line
# balck = cv2.line(black,(835,350),(835,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(1000,350),(1000,400),((0,0,0)),5)#footh_path_line





# road_rectangle_2
black =cv2.rectangle(black,(564,400),(814,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(564,350),(814,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(566,450),(626,450),(255,255,255),1)#middle_line
black= cv2.line(black,(646,450),(706,450),(255,255,255),1)#middle_line
black= cv2.line(black,(726,450),(786,450),(255,255,255),1)#middle_line
black= cv2.line(black,(800,450),(814,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(607,200),(730,327),(215,236,209),-1)#building
black = cv2.rectangle(black,(658,326),(678,296),(86,91,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(630,258),(640,248),(0,255,0),2)# leftwindows_1
black = cv2.rectangle(black,(690,258),(700,248),(0,255,0),2)# windows


#footh_path_line
balck = cv2.line(black,(678,350),(678,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(814,350),(814,400),((0,0,0)),5)#footh_path_line



# road_rectangle_3
black =cv2.rectangle(black,(314,400),(564,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(314,350),(564,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(314,450),(374,450),(255,255,255),1)#middle_line
black= cv2.line(black,(394,450),(456,450),(255,255,255),1)#middle_line
black= cv2.line(black,(466,450),(510,450),(255,255,255),1)#middle_line
black= cv2.line(black,(520,450),(564,450),(255,255,255),1)#middle_line

# building  RGB 
black = cv2.rectangle(black,(400,200),(515,310),(255,0,0),-1)#building
black = cv2.rectangle(black,(440,309),(460,276),(86,210,93),2)#door RGB: (93, 41, 6) 
black = cv2.rectangle(black,(410,258),(425,248),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(475,258),(490,248),(0,133,242),2)# windowsRGB 242, 133, 0


#footh_path_line
balck = cv2.line(black,(430,350),(430,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(561,350),(561,400),((0,0,0)),5)#footh_path_line


# road_rectangle_4
black =cv2.rectangle(black,(0,400),(314,500),(0,0,0),-1)# road_rectangle

# footh_path
black = cv2.rectangle(black,(0,350),(314,400),(0,234,255),-1)# footh_path

#middle_line
black= cv2.line(black,(0,450),(70,450),(255,255,255),1)#middle_line
black= cv2.line(black,(90,450),(160,450),(255,255,255),1)#middle_line
black= cv2.line(black,(190,450),(250,450),(255,255,255),1)#middle_line
black= cv2.line(black,(260,450),(314,450),(255,255,255),1)#middle_line

# building  RGB _3
black = cv2.rectangle(black,(90,180),(220,310),(14,65,183),-1)#building RGB 183, 65, 14
black = cv2.rectangle(black,(140,309),(170,266),(86,210,93),2)#door 
black = cv2.rectangle(black,(105,248),(120,238),(0,133,242),2)# leftwindows_1
black = cv2.rectangle(black,(185,248),(200,238),(0,133,242),2)# windows


#footh_path_line
balck = cv2.line(black,(110,350),(110,400),((0,0,0)),5)#footh_path_line
balck = cv2.line(black,(312,350),(312,400),((0,0,0)),5)#footh_path_line


cv2.imshow("Road",black)
cv2.waitKey()
cv2.destroyAllWindows() 
cv2.imwrite(r"C:\Users\Dell\Documents\Deep_Learning\Open_CV\Open_cv_projects\Images_GIF\Image15.jpg",black)

# %% [markdown]
# # CITIFICATION

# %% [markdown]
# ### day_1

# %%
# night
black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground

black=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
black=cv2.line(black,(145,300),(125,450),(11,71,110),30)
black=cv2.line(black,(145,300),(165,450),(11,71,110),30)
black=cv2.circle(black,(145,250),70,(51,110,0),-2)
black=cv2.circle(black,(90,280),70,(51,110,0),-2)
black=cv2.circle(black,(190,280),70,(51,110,0),-2)

black=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
black=cv2.line(black,(870,300),(850,450),(11,71,110),30)
black=cv2.line(black,(870,300),(890,450),(11,71,110),30)
black=cv2.circle(black,(870,250),70,(51,110,0),-2)
black=cv2.circle(black,(830,280),70,(51,110,0),-2)
black=cv2.circle(black,(900,280),70,(51,110,0),-2)

black=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
black=cv2.line(black,(500,210),(480,500),(11,71,110),50)
black=cv2.line(black,(500,210),(520,500),(11,71,110),50)
black=cv2.circle(black,(500,200),100,(51,110,0),-2)
black=cv2.circle(black,(450,230),90,(51,110,0),-2)
black=cv2.circle(black,(550,230),90,(51,110,0),-2)
black=cv2.circle(black,(435,282),90,(51,110,0),-2)
black=cv2.circle(black,(575,282),70,(51,110,0),-2)

black=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
black=cv2.line(black,(720,290),(710,350),(11,71,110),15)
black=cv2.line(black,(720,290),(730,350),(11,71,110),15)
black=cv2.circle(black,(720,280),30,(51,110,0),-2)
black=cv2.circle(black,(700,285),30,(51,110,0),-2)
black=cv2.circle(black,(740,285),30,(51,110,0),-2)

black=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
black=cv2.circle(black,(170,480),20,(0,90,45),-2)
black=cv2.circle(black,(210,480),20,(0,90,45),-2)
black=cv2.circle(black,(170,490),30,(0,90,45),-2)
black=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
black=cv2.circle(black,(220,420),10,(0,0,200),-2)
black=cv2.circle(black,(230,410),10,(0,0,200),-2)
black=cv2.circle(black,(210,410),10,(0,0,200),-2)
black=cv2.circle(black,(230,430),10,(0,0,200),-2)
black=cv2.circle(black,(210,430),10,(0,0,200),-2)
black=cv2.circle(black,(220,420),5,(0,191,255),-2)
black=cv2.circle(black,(220,420),2,(0,0,0),-2)

black=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
black=cv2.circle(black,(687,440),25,(0,90,45),-2)
black=cv2.circle(black,(720,435),30,(0,90,45),-2)
black=cv2.circle(black,(750,440),20,(0,90,45),-2)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Sun

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,1000),(1000,400),(15,157,18),200)   # morning ground
black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1
black=cv2.circle(black,(250,120),40,(43,172,250),-2) #2

black=cv2.circle(black,(500,50),40,(43,172,250),-2)

black=cv2.circle(black,(750,120),40,(43,172,250),-2) -2
black=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun -1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Moon

black=np.zeros((500,1000,3),np.uint8)

black=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      # night
black=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200)   # night ground

black=cv2.circle(black,(50,250),40,(201,201,201),-2) # moon 1
black=cv2.circle(black,(250,120),40,(201,201,201),-2) -2

black=cv2.circle(black,(500,50),40,(201,201,201),-2)

black=cv2.circle(black,(750,120),40,(201,201,201),-2) -2
black=cv2.circle(black,(950,250),40,(201,201,201),-2) # sun -1

cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# morning
black=np.zeros((500,1000,3),np.uint8)
black=cv2.rectangle(black,(0,1000),(1000,300),(23,154,0),-1)   # ground
black=cv2.rectangle(black,(700,300),(1000,500),(126,138,113),-1)   # Road
black=cv2.rectangle(black,(700,365),(1000,430),(0,0,0),-1)   # Road



black=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #Sky

# black=cv2.rectangle(black)


cv2.imshow("circle",black)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#Image 0 deforestration
black=np.zeros((500,1000,3),np.uint8)

img0=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img0=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

black=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1


img0=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img0=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img0=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img0=cv2.circle(black,(145,250),70,(51,110,0),-2)
img0=cv2.circle(black,(90,280),70,(51,110,0),-2)
img0=cv2.circle(black,(190,280),70,(51,110,0),-2)


img0=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img0=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img0=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img0=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img0=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img0=cv2.line(black,(870,300),(870,450),(11,71,110),30) # Trees 02
img0=cv2.line(black,(870,300),(850,450),(11,71,110),30)
img0=cv2.line(black,(870,300),(890,450),(11,71,110),30)
img0=cv2.circle(black,(870,250),70,(51,110,0),-2)
img0=cv2.circle(black,(830,280),70,(51,110,0),-2)
img0=cv2.circle(black,(900,280),70,(51,110,0),-2)


img0=cv2.circle(black,(900,230),7,(0,255,255),-1)#Oranges2
img0=cv2.circle(black,(800,300),7,(0,255,255),-1)#Oranges2
img0=cv2.circle(black,(946,310),7,(0,255,255),-1)#Oranges2
img0=cv2.circle(black,(816,227),7,(0,255,255),-1)#Oranges2
img0=cv2.circle(black,(871,276),7,(0,255,255),-1)#Oranges2




img0=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
img0=cv2.line(black,(500,210),(480,500),(11,71,110),50)
img0=cv2.line(black,(500,210),(520,500),(11,71,110),50)
img0=cv2.circle(black,(500,200),100,(51,110,0),-2)
img0=cv2.circle(black,(450,230),90,(51,110,0),-2)
img0=cv2.circle(black,(550,230),90,(51,110,0),-2)
img0=cv2.circle(black,(435,282),90,(51,110,0),-2)
img0=cv2.circle(black,(575,282),70,(51,110,0),-2)

img0=cv2.circle(black,(502,295),7,(0,255,255),-1)#Oranges3
img0=cv2.circle(black,(382,292),7,(0,255,255),-1)#Oranges3
img0=cv2.circle(black,(400,200),7,(0,255,255),-1)#Oranges3
img0=cv2.circle(black,(601,266),7,(0,255,255),-1)#Oranges3


img0=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
img0=cv2.line(black,(720,290),(710,350),(11,71,110),15)
img0=cv2.line(black,(720,290),(730,350),(11,71,110),15)
img0=cv2.circle(black,(720,280),30,(51,110,0),-2)
img0=cv2.circle(black,(700,285),30,(51,110,0),-2)
img0=cv2.circle(black,(740,285),30,(51,110,0),-2)

img0=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img0=cv2.circle(black,(170,480),20,(0,90,45),-2)
img0=cv2.circle(black,(210,480),20,(0,90,45),-2)
img0=cv2.circle(black,(170,490),30,(0,90,45),-2)
img0=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img0=cv2.circle(black,(220,420),10,(0,0,200),-2)
img0=cv2.circle(black,(230,410),10,(0,0,200),-2)
img0=cv2.circle(black,(210,410),10,(0,0,200),-2)
img0=cv2.circle(black,(230,430),10,(0,0,200),-2)
img0=cv2.circle(black,(210,430),10,(0,0,200),-2)
img0=cv2.circle(black,(220,420),5,(0,191,255),-2)
img0=cv2.circle(black,(220,420),2,(0,0,0),-2)

img0=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
img0=cv2.circle(black,(687,440),25,(0,90,45),-2)
img0=cv2.circle(black,(720,435),30,(0,90,45),-2)
img0=cv2.circle(black,(750,440),20,(0,90,45),-2)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img0.jpg",img0)

# %%
#Deforestration 1st image

black=np.zeros((500,1000,3),np.uint8)
img1=cv2.rectangle(black,(0,1000),(1000,300),(23,154,0),-1)   # ground
img1=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #Sky
img1=cv2.circle(black,(250,120),40,(43,172,250),-2) #2 sun



img1=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img1=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img1=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img1=cv2.circle(black,(145,250),70,(51,110,0),-2)
img1=cv2.circle(black,(90,280),70,(51,110,0),-2)
img1=cv2.circle(black,(190,280),70,(51,110,0),-20)

img1=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img1=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img1=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img1=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img1=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img1=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
img1=cv2.line(black,(500,210),(480,500),(11,71,110),50)
img1=cv2.line(black,(500,210),(520,500),(11,71,110),50)
img1=cv2.circle(black,(500,200),100,(51,110,0),-2)
img1=cv2.circle(black,(450,230),90,(51,110,0),-2)
img1=cv2.circle(black,(550,230),90,(51,110,0),-2)
img1=cv2.circle(black,(435,282),90,(51,110,0),-2)
img1=cv2.circle(black,(575,282),70,(51,110,0),-2)

img1=cv2.circle(black,(502,295),7,(0,255,255),-1)#Oranges3
img1=cv2.circle(black,(382,292),7,(0,255,255),-1)#Oranges3
img1=cv2.circle(black,(400,200),7,(0,255,255),-1)#Oranges3
img1=cv2.circle(black,(601,266),7,(0,255,255),-1)#Oranges3


img1=cv2.line(black,(720,290),(720,350),(11,71,110),15) # Trees 04
img1=cv2.line(black,(720,290),(710,350),(11,71,110),15)
img1=cv2.line(black,(720,290),(730,350),(11,71,110),15)
img1=cv2.circle(black,(720,280),30,(51,110,0),-2)
img1=cv2.circle(black,(700,285),30,(51,110,0),-2)
img1=cv2.circle(black,(740,285),30,(51,110,0),-2)


img1=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img1=cv2.circle(black,(170,480),20,(0,90,45),-2)
img1=cv2.circle(black,(210,480),20,(0,90,45),-2)
img1=cv2.circle(black,(170,490),30,(0,90,45),-2)

img1=cv2.circle(black,(697,421),30,(0,90,45),-2) # Grass 2
img1=cv2.circle(black,(687,440),25,(0,90,45),-2)
img1=cv2.circle(black,(720,435),30,(0,90,45),-2)
img1=cv2.circle(black,(750,440),20,(0,90,45),-2)

img1=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img1=cv2.circle(black,(220,420),10,(0,0,200),-2)
img1=cv2.circle(black,(230,410),10,(0,0,200),-2)
img1=cv2.circle(black,(210,410),10,(0,0,200),-2)
img1=cv2.circle(black,(230,430),10,(0,0,200),-2)
img1=cv2.circle(black,(210,430),10,(0,0,200),-2)
img1=cv2.circle(black,(220,420),5,(0,191,255),-2)
img1=cv2.circle(black,(220,420),2,(0,0,0),-2)


# Road1
img1=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img1=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road
img1=cv2.line(black,(800,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img1=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings

img1=cv2.rectangle(black,(830,260),(850,280),(255,255,255),-1)   #  window1
img1=cv2.rectangle(black,(830,290),(850,310),(255,255,255),-1)   #  window2



img1=cv2.rectangle(black,(890,260),(870,280),(255,255,255),-1) #window2
img1=cv2.rectangle(black,(890,290),(870,310),(255,255,255),-1) #window2

img1=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR



cv2.imshow("circle",img1)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img1.jpg",img1)

# %%
#Deforestration 2nd image

black=np.zeros((500,1000,3),np.uint8)
img2=cv2.rectangle(black,(0,1000),(1000,300),(23,154,0),-1)   # ground
img2=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #Sky
img2=cv2.circle(black,(500,50),40,(43,172,250),-2)



img2=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img2=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img2=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img2=cv2.circle(black,(145,250),70,(51,110,0),-2)
img2=cv2.circle(black,(90,280),70,(51,110,0),-2)
img2=cv2.circle(black,(190,280),70,(51,110,0),-20)

img2=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img2=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img2=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img2=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img2=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img2=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
img2=cv2.line(black,(500,210),(480,500),(11,71,110),50)
img2=cv2.line(black,(500,210),(520,500),(11,71,110),50)
img2=cv2.circle(black,(500,200),100,(51,110,0),-2)
img2=cv2.circle(black,(450,230),90,(51,110,0),-2)
img2=cv2.circle(black,(550,230),90,(51,110,0),-2)
img2=cv2.circle(black,(435,282),90,(51,110,0),-2)
img2=cv2.circle(black,(575,282),70,(51,110,0),-2)

img2=cv2.circle(black,(502,295),7,(0,255,255),-1)#Oranges3
img2=cv2.circle(black,(382,292),7,(0,255,255),-1)#Oranges3
img2=cv2.circle(black,(400,200),7,(0,255,255),-1)#Oranges3
img2=cv2.circle(black,(601,266),7,(0,255,255),-1)#Oranges3


img2=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img2=cv2.circle(black,(170,480),20,(0,90,45),-2)
img2=cv2.circle(black,(210,480),20,(0,90,45),-2)
img2=cv2.circle(black,(170,490),30,(0,90,45),-2)
img2=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img2=cv2.circle(black,(220,420),10,(0,0,200),-2)
img2=cv2.circle(black,(230,410),10,(0,0,200),-2)
img2=cv2.circle(black,(210,410),10,(0,0,200),-2)
img2=cv2.circle(black,(230,430),10,(0,0,200),-2)
img2=cv2.circle(black,(210,430),10,(0,0,200),-2)
img2=cv2.circle(black,(220,420),5,(0,191,255),-2)
img2=cv2.circle(black,(220,420),2,(0,0,0),-2)


# Road1
img2=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img2=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road
img2=cv2.line(black,(890,450),(850,450),(255,255,255),1)#Road lines
img2=cv2.line(black,(880,450),(930,450),(255,255,255),1)#Road lines
img2=cv2.line(black,(960,450),(1000,450),(255,255,255),1)#Road lines

#Road2
img2=cv2.rectangle(black,(700,300),(1000,500),(126,138,113),-1)   # Concrete floor
img2=cv2.rectangle(black,(700,400),(1000,500),(0,0,0),-1)   # Road
img2=cv2.line(black,(700,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img2=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Building1
img2=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2

#1st building windows
img2=cv2.rectangle(black,(830,260),(850,280),(255,255,255),-1)   #  window11
img2=cv2.rectangle(black,(830,290),(850,310),(255,255,255),-1)   #  window12
#2nd building windows
img2=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img2=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img2=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img2=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img2=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img2=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img2=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img2=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img2=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img2=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img2=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img2=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img2=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img2=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img2=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img2=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)


img2=cv2.rectangle(black,(890,260),(870,280),(255,255,255),-1) #window2
img2=cv2.rectangle(black,(890,290),(870,310),(255,255,255),-1) #window2

img2=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR



cv2.imshow("circle",img2)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img2.jpg",img2)

# %%
#Deforestration 3rd image

black=np.zeros((500,1000,3),np.uint8)
img3=cv2.rectangle(black,(0,1000),(1000,300),(23,154,0),-1)   # ground
img3=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #Sky
img3=cv2.circle(black,(750,120),40,(43,172,250),-2) #Sun



img3=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img3=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img3=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img3=cv2.circle(black,(145,250),70,(51,110,0),-2)
img3=cv2.circle(black,(90,280),70,(51,110,0),-2)
img3=cv2.circle(black,(190,280),70,(51,110,0),-20)

img3=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img3=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img3=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img3=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img3=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img3=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
img3=cv2.line(black,(500,210),(480,500),(11,71,110),50)
img3=cv2.line(black,(500,210),(520,500),(11,71,110),50)
img3=cv2.circle(black,(500,200),100,(51,110,0),-2)
img3=cv2.circle(black,(450,230),90,(51,110,0),-2)
img3=cv2.circle(black,(550,230),90,(51,110,0),-2)
img3=cv2.circle(black,(435,282),90,(51,110,0),-2)
img3=cv2.circle(black,(575,282),70,(51,110,0),-2)

img3=cv2.circle(black,(502,295),7,(0,255,255),-1)#Oranges3
img3=cv2.circle(black,(382,292),7,(0,255,255),-1)#Oranges3
img3=cv2.circle(black,(400,200),7,(0,255,255),-1)#Oranges3
img3=cv2.circle(black,(601,266),7,(0,255,255),-1)#Oranges3


img3=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img3=cv2.circle(black,(170,480),20,(0,90,45),-2)
img3=cv2.circle(black,(210,480),20,(0,90,45),-2)
img3=cv2.circle(black,(170,490),30,(0,90,45),-2)
img3=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img3=cv2.circle(black,(220,420),10,(0,0,200),-2)
img3=cv2.circle(black,(230,410),10,(0,0,200),-2)
img3=cv2.circle(black,(210,410),10,(0,0,200),-2)
img3=cv2.circle(black,(230,430),10,(0,0,200),-2)
img3=cv2.circle(black,(210,430),10,(0,0,200),-2)
img3=cv2.circle(black,(220,420),5,(0,191,255),-2)
img3=cv2.circle(black,(220,420),2,(0,0,0),-2)


# Road1
img3=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img3=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road
img3=cv2.line(black,(890,450),(1000,450),(255,255,255),1)#Road lines

#Road2
img3=cv2.rectangle(black,(650,300),(1000,500),(126,138,113),-1)   # Concrete floor
img3=cv2.rectangle(black,(650,400),(1000,500),(0,0,0),-1)   # Road
img3=cv2.line(black,(650,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img3=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Building1
img3=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img3=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3

#building1 windows
img3=cv2.rectangle(black,(830,260),(850,280),(255,255,255),-1)   #  window1
img3=cv2.rectangle(black,(830,290),(850,310),(255,255,255),-1)   #  window2

#building2 windows
img3=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img3=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img3=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img3=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img3=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img3=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img3=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img3=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img3=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img3=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img3=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img3=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img3=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img3=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img3=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img3=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img3=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img3=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img3=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img3=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img3=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img3=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img3=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img3=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)


img3=cv2.rectangle(black,(890,260),(870,280),(255,255,255),-1) #window2
img3=cv2.rectangle(black,(890,290),(870,310),(255,255,255),-1) #window2

img3=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR



cv2.imshow("circle",img3)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img3.jpg",img3)

# %%
#Deforestration 4th image

black=np.zeros((500,1000,3),np.uint8)
img4=cv2.rectangle(black,(0,1000),(1000,300),(23,154,0),-1)   # ground
img4=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #Sky
img4=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun



img4=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img4=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img4=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img4=cv2.circle(black,(145,250),70,(51,110,0),-2)
img4=cv2.circle(black,(90,280),70,(51,110,0),-2)
img4=cv2.circle(black,(190,280),70,(51,110,0),-20)

img4=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img4=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img4=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img4=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img4=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1


img4=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img4=cv2.circle(black,(170,480),20,(0,90,45),-2)
img4=cv2.circle(black,(210,480),20,(0,90,45),-2)
img4=cv2.circle(black,(170,490),30,(0,90,45),-2)
img4=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img4=cv2.circle(black,(220,420),10,(0,0,200),-2)
img4=cv2.circle(black,(230,410),10,(0,0,200),-2)
img4=cv2.circle(black,(210,410),10,(0,0,200),-2)
img4=cv2.circle(black,(230,430),10,(0,0,200),-2)
img4=cv2.circle(black,(210,430),10,(0,0,200),-2)
img4=cv2.circle(black,(220,420),5,(0,191,255),-2)
img4=cv2.circle(black,(220,420),2,(0,0,0),-2)


img4=cv2.line(black,(500,210),(500,500),(11,71,110),50) # Trees 03
img4=cv2.line(black,(500,210),(480,500),(11,71,110),50)
img4=cv2.line(black,(500,210),(520,500),(11,71,110),50)
img4=cv2.circle(black,(500,200),100,(51,110,0),-2)
img4=cv2.circle(black,(450,230),90,(51,110,0),-2)
img4=cv2.circle(black,(550,230),90,(51,110,0),-2)
img4=cv2.circle(black,(435,282),90,(51,110,0),-2)
img4=cv2.circle(black,(575,282),70,(51,110,0),-2)

img4=cv2.circle(black,(502,295),7,(0,255,255),-1)#Oranges3
img4=cv2.circle(black,(382,292),7,(0,255,255),-1)#Oranges3
img4=cv2.circle(black,(400,200),7,(0,255,255),-1)#Oranges3
img4=cv2.circle(black,(601,266),7,(0,255,255),-1)#Oranges3


# Road1
img4=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img4=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img4=cv2.rectangle(black,(650,300),(1000,500),(126,138,113),-1)   # Concrete floor
img4=cv2.rectangle(black,(650,400),(1000,500),(0,0,0),-1)   # Road
img4=cv2.line(black,(650,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img4=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Building
img4=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img4=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3


#building1 windows

img4=cv2.rectangle(black,(830,260),(850,280),(255,255,255),-1)   #  window1
img4=cv2.rectangle(black,(830,290),(850,310),(255,255,255),-1)   #  window2

#building2 windows
img4=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img4=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img4=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img4=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img4=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img4=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img4=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img4=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img4=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img4=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img4=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img4=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img4=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img4=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img4=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img4=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img4=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img4=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img4=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img4=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img4=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img4=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img4=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img4=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)



img4=cv2.rectangle(black,(890,260),(870,280),(255,255,255),-1) #window2
img4=cv2.rectangle(black,(890,290),(870,310),(255,255,255),-1) #window2

img4=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR



cv2.imshow("circle",img4)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img4.jpg",img4)

# %% [markdown]
# ### night_1

# %%
# night  5th Image
black=np.zeros((500,1000,3),np.uint8)

img5=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img5=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img5=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1


img5=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img5=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img5=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img5=cv2.circle(black,(145,250),70,(51,110,0),-2)
img5=cv2.circle(black,(90,280),70,(51,110,0),-2)
img5=cv2.circle(black,(190,280),70,(51,110,0),-2)

img5=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img5=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img5=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img5=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img5=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1

img5=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img5=cv2.circle(black,(170,480),20,(0,90,45),-2)
img5=cv2.circle(black,(210,480),20,(0,90,45),-2)
img5=cv2.circle(black,(170,490),30,(0,90,45),-2)
img5=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img5=cv2.circle(black,(220,420),10,(0,0,200),-2)
img5=cv2.circle(black,(230,410),10,(0,0,200),-2)
img5=cv2.circle(black,(210,410),10,(0,0,200),-2)
img5=cv2.circle(black,(230,430),10,(0,0,200),-2)
img5=cv2.circle(black,(210,430),10,(0,0,200),-2)
img5=cv2.circle(black,(220,420),5,(0,191,255),-2)
img5=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img5=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img5=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img5=cv2.rectangle(black,(650,300),(1000,500),(126,138,113),-1)   # Concrete floor
img5=cv2.rectangle(black,(650,400),(1000,500),(0,0,0),-1)   # Road

img5=cv2.line(black,(650,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img5=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img5=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img5=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3

img5=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img5=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2

img5=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img5=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

#building2 windows
img5=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img5=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img5=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img5=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img5=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img5=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img5=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img5=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img5=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img5=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img5=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img5=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img5=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img5=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img5=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img5=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img5=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img5=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img5=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img5=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img5=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img5=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img5=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img5=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

img5=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR



cv2.imshow("circle",img5)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img5.jpg",img5)

# %%
# night 6th image

black=np.zeros((500,1000,3),np.uint8)

img6=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img6=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img6=cv2.circle(black,(250,120),30,(201,201,201),-2) #moon


img6=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img6=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img6=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img6=cv2.circle(black,(145,250),70,(51,110,0),-2)
img6=cv2.circle(black,(90,280),70,(51,110,0),-2)
img6=cv2.circle(black,(190,280),70,(51,110,0),-2)

img6=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img6=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img6=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img6=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img6=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1

img6=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img6=cv2.circle(black,(170,480),20,(0,90,45),-2)
img6=cv2.circle(black,(210,480),20,(0,90,45),-2)
img6=cv2.circle(black,(170,490),30,(0,90,45),-2)
img6=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img6=cv2.circle(black,(220,420),10,(0,0,200),-2)
img6=cv2.circle(black,(230,410),10,(0,0,200),-2)
img6=cv2.circle(black,(210,410),10,(0,0,200),-2)
img6=cv2.circle(black,(230,430),10,(0,0,200),-2)
img6=cv2.circle(black,(210,430),10,(0,0,200),-2)
img6=cv2.circle(black,(220,420),5,(0,191,255),-2)
img6=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img6=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img6=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img6=cv2.rectangle(black,(550,300),(1000,500),(126,138,113),-1)   # Concrete floor
img6=cv2.rectangle(black,(550,400),(1000,500),(0,0,0),-1)   # Road

img6=cv2.line(black,(550,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img6=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Building1
img6=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img6=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3

img6=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img6=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2

img6=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img6=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img6=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img6=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img6=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img6=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img6=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img6=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img6=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img6=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img6=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img6=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img6=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img6=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img6=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img6=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img6=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img6=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img6=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img6=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img6=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img6=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img6=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img6=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img6=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img6=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img6=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

cv2.imshow("circle",img6)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img6.jpg",img6)

# %%
# night 7th image

black=np.zeros((500,1000,3),np.uint8)

img7=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img7=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img7=cv2.circle(black,(500,50),30,(201,201,201),-2) #moon


img7=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img7=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img7=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img7=cv2.circle(black,(145,250),70,(51,110,0),-2)
img7=cv2.circle(black,(90,280),70,(51,110,0),-2)
img7=cv2.circle(black,(190,280),70,(51,110,0),-2)

img7=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img7=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img7=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img7=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img7=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1

img7=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img7=cv2.circle(black,(170,480),20,(0,90,45),-2)
img7=cv2.circle(black,(210,480),20,(0,90,45),-2)
img7=cv2.circle(black,(170,490),30,(0,90,45),-2)
img7=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img7=cv2.circle(black,(220,420),10,(0,0,200),-2)
img7=cv2.circle(black,(230,410),10,(0,0,200),-2)
img7=cv2.circle(black,(210,410),10,(0,0,200),-2)
img7=cv2.circle(black,(230,430),10,(0,0,200),-2)
img7=cv2.circle(black,(210,430),10,(0,0,200),-2)
img7=cv2.circle(black,(220,420),5,(0,191,255),-2)
img7=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img7=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img7=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img7=cv2.rectangle(black,(450,300),(1000,500),(126,138,113),-1)   # Concrete floor
img7=cv2.rectangle(black,(450,400),(1000,500),(0,0,0),-1)   # Road

img7=cv2.line(black,(450,450),(1000,450),(255,255,255),1)#Road lines

#Building 
img7=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img7=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img7=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img7=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
#building 4 windows
img7=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img7=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img7=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img7=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img7=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img7=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img7=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img7=cv2.line(black,(670,310),(690,310),(0,0,0),1)



img7=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img7=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2

img7=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img7=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img7=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR
#building2 windows
img7=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img7=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img7=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img7=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img7=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img7=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img7=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img7=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img7=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img7=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img7=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img7=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img7=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img7=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img7=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img7=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img7=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img7=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img7=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img7=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img7=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img7=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img7=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img7=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)


cv2.imshow("circle",img7)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img7.jpg",img7)

# %%
# night 8th image

black=np.zeros((500,1000,3),np.uint8)

img8=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img8=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img8=cv2.circle(black,(750,120),30,(201,201,201),-2) #moon


img8=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img8=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img8=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img8=cv2.circle(black,(145,250),70,(51,110,0),-2)
img8=cv2.circle(black,(90,280),70,(51,110,0),-2)
img8=cv2.circle(black,(190,280),70,(51,110,0),-2)

img8=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img8=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img8=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img8=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img8=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1

img8=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img8=cv2.circle(black,(170,480),20,(0,90,45),-2)
img8=cv2.circle(black,(210,480),20,(0,90,45),-2)
img8=cv2.circle(black,(170,490),30,(0,90,45),-2)
img8=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img8=cv2.circle(black,(220,420),10,(0,0,200),-2)
img8=cv2.circle(black,(230,410),10,(0,0,200),-2)
img8=cv2.circle(black,(210,410),10,(0,0,200),-2)
img8=cv2.circle(black,(230,430),10,(0,0,200),-2)
img8=cv2.circle(black,(210,430),10,(0,0,200),-2)
img8=cv2.circle(black,(220,420),5,(0,191,255),-2)
img8=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img8=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img8=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img8=cv2.rectangle(black,(350,300),(1000,500),(126,138,113),-1)   # Concrete floor
img8=cv2.rectangle(black,(350,400),(1000,500),(0,0,0),-1)   # Road
 
img8=cv2.line(black,(350,450),(1000,450),(255,255,255),1)#Road lines

#Building 1 
img8=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img8=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img8=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img8=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4


img8=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img8=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2

img8=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img8=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img8=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img8=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img8=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img8=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img8=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img8=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img8=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img8=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img8=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img8=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img8=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img8=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img8=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img8=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img8=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img8=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img8=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img8=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img8=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img8=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img8=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img8=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img8=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img8=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img8=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img8=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img8=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img8=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img8=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img8=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img8=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img8=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img8=cv2.line(black,(670,310),(690,310),(0,0,0),1)


cv2.imshow("circle",img8)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img8.jpg",img8)

# %%
# night 9th image

black=np.zeros((500,1000,3),np.uint8)

img9=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img9=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img9=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon 


img9=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img9=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img9=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img9=cv2.circle(black,(145,250),70,(51,110,0),-2)
img9=cv2.circle(black,(90,280),70,(51,110,0),-2)
img9=cv2.circle(black,(190,280),70,(51,110,0),-2)

img9=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img9=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img9=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img9=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img9=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1

img9=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img9=cv2.circle(black,(170,480),20,(0,90,45),-2)
img9=cv2.circle(black,(210,480),20,(0,90,45),-2)
img9=cv2.circle(black,(170,490),30,(0,90,45),-2)
img9=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img9=cv2.circle(black,(220,420),10,(0,0,200),-2)
img9=cv2.circle(black,(230,410),10,(0,0,200),-2)
img9=cv2.circle(black,(210,410),10,(0,0,200),-2)
img9=cv2.circle(black,(230,430),10,(0,0,200),-2)
img9=cv2.circle(black,(210,430),10,(0,0,200),-2)
img9=cv2.circle(black,(220,420),5,(0,191,255),-2)
img9=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img9=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img9=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road

#Road2
img9=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img9=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road

img9=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img9=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img9=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img9=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img9=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4


img9=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img9=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2

img9=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img9=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img9=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR
#building2 windows
img9=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img9=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img9=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img9=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img9=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img9=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img9=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img9=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img9=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img9=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img9=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img9=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img9=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img9=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img9=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img9=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img9=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img9=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img9=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img9=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img9=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img9=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img9=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img9=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img9=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img9=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img9=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img9=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img9=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img9=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img9=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img9=cv2.line(black,(670,310),(690,310),(0,0,0),1)


cv2.imshow("circle",img9)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img9.jpg",img9)

# %% [markdown]
# ### day_2

# %%
#Image 10 deforestration
black=np.zeros((500,1000,3),np.uint8)

img10=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img10=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

img10=cv2.circle(black,(50,250),40,(43,172,250),-2) # sun 1


img10=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img10=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img10=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img10=cv2.circle(black,(145,250),70,(51,110,0),-2)
img10=cv2.circle(black,(90,280),70,(51,110,0),-2)
img10=cv2.circle(black,(190,280),70,(51,110,0),-2)


img10=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img10=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img10=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img10=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img10=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img10=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img10=cv2.circle(black,(170,480),20,(0,90,45),-2)
img10=cv2.circle(black,(210,480),20,(0,90,45),-2)
img10=cv2.circle(black,(170,490),30,(0,90,45),-2)
img10=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img10=cv2.circle(black,(220,420),10,(0,0,200),-2)
img10=cv2.circle(black,(230,410),10,(0,0,200),-2)
img10=cv2.circle(black,(210,410),10,(0,0,200),-2)
img10=cv2.circle(black,(230,430),10,(0,0,200),-2)
img10=cv2.circle(black,(210,430),10,(0,0,200),-2)
img10=cv2.circle(black,(220,420),5,(0,191,255),-2)
img10=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img10=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img10=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img10=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img10=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road

img10=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines



#Building 1 
img10=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img10=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img10=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img10=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4


img10=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img10=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2



img10=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img10=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img10=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR


#building2 windows
img10=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img10=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img10=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img10=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img10=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img10=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img10=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img10=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img10=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img10=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img10=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img10=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img10=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img10=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img10=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img10=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img10=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img10=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img10=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img10=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img10=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img10=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img10=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img10=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img10=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img10=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img10=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img10=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img10=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img10=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img10=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img10=cv2.line(black,(670,310),(690,310),(0,0,0),1)


cv2.imshow("circle",img10)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img10.jpg",img10)

# %%
#Image 11 deforestration
black=np.zeros((500,1000,3),np.uint8)

img11=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img11=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

img11=cv2.circle(black,(250,120),40,(43,172,250),-2) # sun


img11=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img11=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img11=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img11=cv2.circle(black,(145,250),70,(51,110,0),-2)
img11=cv2.circle(black,(90,280),70,(51,110,0),-2)
img11=cv2.circle(black,(190,280),70,(51,110,0),-2)


img11=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img11=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img11=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img11=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img11=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img11=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img11=cv2.circle(black,(170,480),20,(0,90,45),-2)
img11=cv2.circle(black,(210,480),20,(0,90,45),-2)
img11=cv2.circle(black,(170,490),30,(0,90,45),-2)
img11=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img11=cv2.circle(black,(220,420),10,(0,0,200),-2)
img11=cv2.circle(black,(230,410),10,(0,0,200),-2)
img11=cv2.circle(black,(210,410),10,(0,0,200),-2)
img11=cv2.circle(black,(230,430),10,(0,0,200),-2)
img11=cv2.circle(black,(210,430),10,(0,0,200),-2)
img11=cv2.circle(black,(220,420),5,(0,191,255),-2)
img11=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img11=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img11=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road

#Road2
img11=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img11=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road
img11=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img11=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img11=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img11=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img11=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img11=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)#Building5


img11=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img11=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2



img11=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img11=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img11=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR


#building2 windows
img11=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img11=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img11=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img11=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img11=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img11=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img11=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img11=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img11=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img11=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img11=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img11=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img11=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img11=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img11=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img11=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img11=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img11=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img11=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img11=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img11=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img11=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img11=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img11=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img11=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img11=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img11=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img11=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img11=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img11=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img11=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img11=cv2.line(black,(670,310),(690,310),(0,0,0),1)


cv2.imshow("circle",img11)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img11.jpg",img11)

# %%
#Image 12 deforestration
black=np.zeros((500,1000,3),np.uint8)

img12=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img12=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

img12=cv2.circle(black,(500,50),40,(43,172,250),-2)


img12=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img12=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img12=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img12=cv2.circle(black,(145,250),70,(51,110,0),-2)
img12=cv2.circle(black,(90,280),70,(51,110,0),-2)
img12=cv2.circle(black,(190,280),70,(51,110,0),-2)


img12=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img12=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img12=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img12=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img12=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img12=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img12=cv2.circle(black,(170,480),20,(0,90,45),-2)
img12=cv2.circle(black,(210,480),20,(0,90,45),-2)
img12=cv2.circle(black,(170,490),30,(0,90,45),-2)
img12=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img12=cv2.circle(black,(220,420),10,(0,0,200),-2)
img12=cv2.circle(black,(230,410),10,(0,0,200),-2)
img12=cv2.circle(black,(210,410),10,(0,0,200),-2)
img12=cv2.circle(black,(230,430),10,(0,0,200),-2)
img12=cv2.circle(black,(210,430),10,(0,0,200),-2)
img12=cv2.circle(black,(220,420),5,(0,191,255),-2)
img12=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img12=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img12=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img12=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img12=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road
img12=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img12=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img12=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img12=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img12=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img12=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5


img12=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img12=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2



img12=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img12=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img12=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img12=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img12=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img12=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img12=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img12=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img12=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img12=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img12=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img12=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img12=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img12=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img12=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img12=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img12=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img12=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img12=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img12=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img12=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img12=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img12=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img12=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img12=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img12=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img12=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img12=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img12=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img12=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img12=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img12=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img12=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img12=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img12=cv2.line(black,(670,310),(690,310),(0,0,0),1)

#Building 5
img12=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img12=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img12=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img12=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img12=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img12=cv2.line(black,(280,270),(630,270),(255,255,255),1)




cv2.imshow("circle",img12)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite("C:/Users/hp/Desktop/CV_project/img12.jpg",img12)

# %%
#Image 13 deforestration
black=np.zeros((500,1000,3),np.uint8)

img13=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img13=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

img3=cv2.circle(black,(750,120),40,(43,172,250),-2) #Sun


img13=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img13=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img13=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img13=cv2.circle(black,(145,250),70,(51,110,0),-2)
img13=cv2.circle(black,(90,280),70,(51,110,0),-2)
img13=cv2.circle(black,(190,280),70,(51,110,0),-2)


img13=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img13=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img13=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img13=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img13=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img13=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img13=cv2.circle(black,(170,480),20,(0,90,45),-2)
img13=cv2.circle(black,(210,480),20,(0,90,45),-2)
img13=cv2.circle(black,(170,490),30,(0,90,45),-2)
img13=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img13=cv2.circle(black,(220,420),10,(0,0,200),-2)
img13=cv2.circle(black,(230,410),10,(0,0,200),-2)
img13=cv2.circle(black,(210,410),10,(0,0,200),-2)
img13=cv2.circle(black,(230,430),10,(0,0,200),-2)
img13=cv2.circle(black,(210,430),10,(0,0,200),-2)
img13=cv2.circle(black,(220,420),5,(0,191,255),-2)
img13=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img13=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img13=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img13=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img13=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road
img13=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img13=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img13=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img13=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img13=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img13=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5


img13=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img13=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2



img13=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img13=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img13=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img13=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img13=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img13=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img13=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img13=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img13=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img13=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img13=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img13=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img13=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img13=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img13=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img13=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img13=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img13=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img13=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img13=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img13=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img13=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img13=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img13=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img13=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img13=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img13=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img13=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img13=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img13=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img13=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img13=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img13=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img13=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img13=cv2.line(black,(670,310),(690,310),(0,0,0),1)

#Building 5
img13=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img13=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img13=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img13=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img13=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img13=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img13)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img13.jpg",img13)

# %%
#Image 14 deforestration
black=np.zeros((500,1000,3),np.uint8)

img14=cv2.rectangle(black,(0,1000),(1000,400),(23,154,0),200)   # morning ground
img14=cv2.rectangle(black,(0,0),(1000,200),(244,191,155),200) #day

img14=cv2.circle(black,(950,250),40,(43,172,250),-2) # sun


img14=cv2.line(black,(145,300),(145,450),(11,71,110),30) # Trees 01
img14=cv2.line(black,(145,300),(125,450),(11,71,110),30)
img14=cv2.line(black,(145,300),(165,450),(11,71,110),30)
img14=cv2.circle(black,(145,250),70,(51,110,0),-2)
img14=cv2.circle(black,(90,280),70,(51,110,0),-2)
img14=cv2.circle(black,(190,280),70,(51,110,0),-2)


img14=cv2.circle(black,(145,250),7,(0,255,255),-2) #Oranges1
img14=cv2.circle(black,(120,280),7,(0,255,255),-2)#Oranges1
img14=cv2.circle(black,(50,280),7,(0,255,255),-2)#Oranges1
img14=cv2.circle(black,(180,220),7,(0,255,255),-2)#Oranges1
img14=cv2.circle(black,(190,280),7,(0,255,255),-2)#Oranges1



img14=cv2.circle(black,(190,461),20,(0,90,45),-2) # Grass 1
img14=cv2.circle(black,(170,480),20,(0,90,45),-2)
img14=cv2.circle(black,(210,480),20,(0,90,45),-2)
img14=cv2.circle(black,(170,490),30,(0,90,45),-2)
img14=cv2.line(black,(200,461),(220,420),(0,200,150),2)# flower
img14=cv2.circle(black,(220,420),10,(0,0,200),-2)
img14=cv2.circle(black,(230,410),10,(0,0,200),-2)
img14=cv2.circle(black,(210,410),10,(0,0,200),-2)
img14=cv2.circle(black,(230,430),10,(0,0,200),-2)
img14=cv2.circle(black,(210,430),10,(0,0,200),-2)
img14=cv2.circle(black,(220,420),5,(0,191,255),-2)
img14=cv2.circle(black,(220,420),2,(0,0,0),-2)

# Road1
img14=cv2.rectangle(black,(800,300),(1000,500),(126,138,113),-1)   # Concrete floor
img14=cv2.rectangle(black,(800,400),(1000,500),(0,0,0),-1)   # Road


#Road2
img14=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img14=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road
img14=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img14=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img14=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img14=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img14=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img14=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5


img14=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img14=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img14=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img14=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img14=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img14=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img14=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img14=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img14=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img14=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img14=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img14=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img14=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img14=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img14=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img14=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img14=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img14=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img14=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img14=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img14=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img14=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img14=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img14=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img14=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img14=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img14=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img14=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img14=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img14=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img14=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img14=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img14=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img14=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img14=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img14=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img14=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img14=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img14=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img14=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img14=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img14=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img14=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img14)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite("C:/Users/hp/Desktop/CV_project/img14.jpg",img14)

# %% [markdown]
# ### night_2

# %%
# night  15th Image
black=np.zeros((500,1000,3),np.uint8)

img15=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img15=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img15=cv2.circle(black,(50,250),30,(201,201,201),-2) # moon 1



img15=cv2.rectangle(black,(255,300),(1000,500),(126,138,113),-1)   # Concrete floor
img15=cv2.rectangle(black,(255,400),(1000,500),(0,0,0),-1)   # Road
img15=cv2.line(black,(255,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img15=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img15=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img15=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img15=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img15=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5


img15=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img15=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img15=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img15=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img15=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img15=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img15=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img15=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img15=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img15=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img15=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img15=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img15=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img15=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img15=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img15=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img15=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img15=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img15=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img15=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img15=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img15=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img15=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img15=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img15=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img15=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img15=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img15=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img15=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img15=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img15=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img15=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img15=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img15=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img15=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img15=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img15=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img15=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img15=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img15=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img15=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img15=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img15=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img15)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite("C:/Users/hp/Desktop/CV_project/img15.jpg",img15)

# %%
# night  16th Image
black=np.zeros((500,1000,3),np.uint8)

img16=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img16=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img16=cv2.circle(black,(250,120),30,(201,201,201),-2) #moon



img16=cv2.rectangle(black,(0,300),(1000,500),(126,138,113),-1)   # Concrete floor
img16=cv2.rectangle(black,(0,400),(1000,500),(0,0,0),-1)   # Road
img16=cv2.line(black,(0,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img16=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img16=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img16=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img16=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img16=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5


img16=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img16=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img16=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img16=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img16=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img16=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img16=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img16=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img16=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img16=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img16=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img16=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img16=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img16=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img16=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img16=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img16=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img16=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img16=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img16=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img16=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img16=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img16=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img16=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img16=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img16=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img16=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img16=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img16=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img16=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img16=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img16=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img16=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img16=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img16=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img16=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img16=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img16=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img16=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img16=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img16=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img16=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img16=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img16)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img16.jpg",img16)

# %%
# night  17th Image
black=np.zeros((500,1000,3),np.uint8)

img17=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img17=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img17=cv2.circle(black,(500,50),30,(201,201,201),-2) #moon

img17=cv2.rectangle(black,(0,300),(1000,500),(126,138,113),-1)   # Concrete floor
img17=cv2.rectangle(black,(0,400),(1000,500),(0,0,0),-1)   # Road
img17=cv2.line(black,(0,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img17=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img17=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img17=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img17=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img17=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5
img17=cv2.rectangle(black,(150,50),(220,340),(28,0,255),-1)# Buililding 6
img17=cv2.rectangle(black,(160,60),(210,320),(192,192,192),-1)
img17=cv2.line(black,(160,100),(210,100),(255,255,255),1)
img17=cv2.line(black,(160,150),(210,150),(255,255,255),1)
img17=cv2.line(black,(160,200),(210,200),(255,255,255),1)
img17=cv2.line(black,(160,250),(210,250),(255,255,255),1)


img17=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img17=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img17=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img17=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img17=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img17=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img17=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img17=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img17=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img17=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img17=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img17=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img17=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img17=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img17=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img17=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img17=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img17=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img17=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img17=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img17=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img17=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img17=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img17=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img17=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img17=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img17=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img17=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img17=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img17=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img17=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img17=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img17=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img17=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img17=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img17=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img17=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img17=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img17=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img17=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img17=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img17=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img17=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img17)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img17.jpg",img17)

# %%
# night  16th Image
black=np.zeros((500,1000,3),np.uint8)

img18=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img18=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img18=cv2.circle(black,(500,50),30,(201,201,201),-2) #moon



img18=cv2.rectangle(black,(0,300),(1000,500),(126,138,113),-1)   # Concrete floor
img18=cv2.rectangle(black,(0,400),(1000,500),(0,0,0),-1)   # Road
img18=cv2.line(black,(0,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img18=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img18=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img18=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img18=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img18=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5
img18=cv2.rectangle(black,(150,50),(220,340),(28,0,255),-1)# Buililding 6
img18=cv2.rectangle(black,(160,60),(210,320),(192,192,192),-1)
img18=cv2.line(black,(160,100),(210,100),(255,255,255),1)
img18=cv2.line(black,(160,150),(210,150),(255,255,255),1)
img18=cv2.line(black,(160,200),(210,200),(255,255,255),1)
img18=cv2.line(black,(160,250),(210,250),(255,255,255),1)




img18=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img18=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img18=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img18=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img18=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img18=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img18=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img18=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img18=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img18=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img18=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img18=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img18=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img18=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img18=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img18=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img18=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img18=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img18=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img18=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img18=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img18=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img18=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img18=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img18=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img18=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img18=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img18=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img18=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img18=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img18=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img18=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img18=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img18=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img18=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img18=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img18=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img18=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img18=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img18=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img18=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img18=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img18=cv2.line(black,(280,270),(630,270),(255,255,255),1)



cv2.imshow("circle",img18)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img18.jpg",img18)

# %%
# night  19th Image
black=np.zeros((500,1000,3),np.uint8)

img19=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img19=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img19=cv2.circle(black,(750,120),30,(201,201,201),-2) #moon



img19=cv2.rectangle(black,(0,300),(1000,500),(126,138,113),-1)   # Concrete floor
img19=cv2.rectangle(black,(0,400),(1000,500),(0,0,0),-1)   # Road
img19=cv2.line(black,(0,450),(1000,450),(255,255,255),1)#Road lines




#Building 1 
img19=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img19=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img19=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img19=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img19=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5
img19=cv2.rectangle(black,(150,50),(220,340),(28,0,255),-1)# Buililding 6
img19=cv2.rectangle(black,(90,20),(140,340),(28,0,25),-1)# Buililding 7
img19=cv2.rectangle(black,(100,30),(130,320),(192,192,192),-1)

img19=cv2.rectangle(black,(100,50),(130,50),(192,192,192),-1)


img19=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img19=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img19=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img19=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img19=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img19=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img19=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img19=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img19=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img19=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img19=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img19=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img19=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img19=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img19=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img19=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img19=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img19=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img19=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img19=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img19=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img19=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img19=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img19=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img19=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img19=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img19=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img19=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img19=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img19=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img19=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img19=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img19=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img19=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img19=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img19=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img19=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img19=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img19=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img19=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img19=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img19=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img19=cv2.line(black,(280,270),(630,270),(255,255,255),1)

#Building6 Windows
img19=cv2.rectangle(black,(160,60),(210,320),(192,192,192),-1)
img19=cv2.line(black,(160,100),(210,100),(255,255,255),1)
img19=cv2.line(black,(160,150),(210,150),(255,255,255),1)
img19=cv2.line(black,(160,200),(210,200),(255,255,255),1)
img19=cv2.line(black,(160,250),(210,250),(255,255,255),1)


img19=cv2.line(black,(100,100),(130,100),(0,0,0),1)
img19=cv2.line(black,(100,150),(130,150),(0,0,0),1)
img19=cv2.line(black,(100,200),(130,200),(0,0,0),1)
img19=cv2.line(black,(100,250),(130,250),(0,0,0),1)


cv2.imshow("circle",img19)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img19.jpg",img19)

# %%
# night  20th Image
black=np.zeros((500,1000,3),np.uint8)

img20=cv2.rectangle(black,(0,0),(1000,200),(84,84,84),200)      #night
img20=cv2.rectangle(black,(0,1000),(1000,400),(59,94,53),200) # night ground
img20=cv2.circle(black,(950,250),30,(201,201,201),-2) # moon 


img20=cv2.rectangle(black,(0,300),(1000,500),(126,138,113),-1)   # Concrete floor
img20=cv2.rectangle(black,(0,400),(1000,500),(0,0,0),-1)   # Road
img20=cv2.line(black,(0,450),(1000,450),(255,255,255),1)#Road lines


#Building 1 
img20=cv2.rectangle(black,(820,250),(900,340),(0,255,255),-1)   #  Buildings
img20=cv2.rectangle(black,(710,150),(810,340),(0,205,100),-1)   #  Building2
img20=cv2.rectangle(black,(910,200),(980,340),(255,255,255),-1) #Building3
img20=cv2.rectangle(black,(660,90),(700,340),(255,108,175),-1) #Building4
img20=cv2.rectangle(black,(260,100),(650,340),(208,253,255),-1)# Buililding 5
img20=cv2.rectangle(black,(150,50),(220,340),(28,0,255),-1)# Buililding 6
img20=cv2.rectangle(black,(90,20),(140,340),(28,0,25),-1)# Buililding 7
img20=cv2.rectangle(black,(100,30),(130,320),(192,192,192),-1)


img20=cv2.rectangle(black,(830,260),(850,280),(255,255,204),-1)   #  window1
img20=cv2.rectangle(black,(830,290),(850,310),(255,255,204),-1)   #  window2


img20=cv2.rectangle(black,(890,260),(870,280),(255,255,204),-1) #window2
img20=cv2.rectangle(black,(890,290),(870,310),(255,255,204),-1) #window2

img20=cv2.rectangle(black,(855,320),(870,340),(0,0,255),-1)   #  Building DOOR

#building2 windows
img20=cv2.rectangle(black,(720,155),(740,170),(0,0,0),-1)
img20=cv2.rectangle(black,(720,175),(740,190),(0,0,0),-1)
img20=cv2.rectangle(black,(720,195),(740,210),(0,0,0),-1)
img20=cv2.rectangle(black,(720,215),(740,230),(0,0,0),-1)
img20=cv2.rectangle(black,(720,235),(740,250),(0,0,0),-1)
img20=cv2.rectangle(black,(720,255),(740,270),(0,0,0),-1)
img20=cv2.rectangle(black,(720,275),(740,290),(0,0,0),-1)
img20=cv2.rectangle(black,(720,295),(740,310),(0,0,0),-1)

img20=cv2.rectangle(black,(780,155),(800,170),(0,0,0),-1)
img20=cv2.rectangle(black,(780,175),(800,190),(0,0,0),-1)
img20=cv2.rectangle(black,(780,195),(800,210),(0,0,0),-1)
img20=cv2.rectangle(black,(780,215),(800,230),(0,0,0),-1)
img20=cv2.rectangle(black,(780,235),(800,250),(0,0,0),-1)
img20=cv2.rectangle(black,(780,255),(800,270),(0,0,0),-1)
img20=cv2.rectangle(black,(780,275),(800,290),(0,0,0),-1)
img20=cv2.rectangle(black,(780,295),(800,310),(0,0,0),-1)

#Building3 Windows
img20=cv2.rectangle(black,(915,210),(930,230),(0,0,0),-1)
img20=cv2.rectangle(black,(915,235),(930,255),(0,0,0),-1)
img20=cv2.rectangle(black,(915,260),(930,280),(0,0,0),-1)
img20=cv2.rectangle(black,(915,285),(930,305),(0,0,0),-1)

img20=cv2.rectangle(black,(960,210),(975,230),(0,0,0),-1)
img20=cv2.rectangle(black,(960,235),(975,255),(0,0,0),-1)
img20=cv2.rectangle(black,(960,260),(975,280),(0,0,0),-1)
img20=cv2.rectangle(black,(960,285),(975,305),(0,0,0),-1)

#Building4 Windows
img20=cv2.rectangle(black,(670,100),(690,320),(192,192,192),-1)
img20=cv2.line(black,(670,130),(690,130),(0,0,0),1)
img20=cv2.line(black,(670,160),(690,160),(0,0,0),1)
img20=cv2.line(black,(670,190),(690,190),(0,0,0),1)
img20=cv2.line(black,(670,220),(690,220),(0,0,0),1)
img20=cv2.line(black,(670,250),(690,250),(0,0,0),1)
img20=cv2.line(black,(670,280),(690,280),(0,0,0),1)
img20=cv2.line(black,(670,310),(690,310),(0,0,0),1)


#Building 5
img20=cv2.rectangle(black,(280,120),(630,300),(144,128,112),-1)
img20=cv2.line(black,(280,150),(630,150),(255,255,255),1)
img20=cv2.line(black,(280,180),(630,180),(255,255,255),1)
img20=cv2.line(black,(280,210),(630,210),(255,255,255),1)
img20=cv2.line(black,(280,240),(630,240),(255,255,255),1)
img20=cv2.line(black,(280,270),(630,270),(255,255,255),1)

#Building6 Windows
img20=cv2.rectangle(black,(160,60),(210,320),(192,192,192),-1)
img20=cv2.line(black,(160,100),(210,100),(255,255,255),1)
img20=cv2.line(black,(160,150),(210,150),(255,255,255),1)
img20=cv2.line(black,(160,200),(210,200),(255,255,255),1)
img20=cv2.line(black,(160,250),(210,250),(255,255,255),1)

#building 7 windows
img20=cv2.rectangle(black,(100,30),(130,320),(192,192,192),-1)
img20=cv2.line(black,(100,100),(130,100),(0,0,0),1)
img20=cv2.line(black,(100,150),(130,150),(0,0,0),1)
img20=cv2.line(black,(100,200),(130,200),(0,0,0),1)
img20=cv2.line(black,(100,250),(130,250),(0,0,0),1)


cv2.imshow("circle",img20)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("C:/Users/hp/Desktop/CV_project/img20.jpg",img20)

# %% [markdown]
# # GIF

# %%
count=0
while True :
    imgf=cv2.imread(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_3\images\img{}.jpg".format(count))
    cv2.imshow("gif",imgf)
    if cv2.waitKey(500) & 255 == ord("q"):
        break
    count=count+1
    if count==118:
        count=1
cv2.destroyAllWindows()
